# %%
k = {11,22,44}
k.add(96)
print(k)
# Out:
# {96, 11, 44, 22}

# %%
k = {2,3,4,5,6}
k.remove(5)
print(k)
# Out:
# {2, 3, 4, 6}

# %%
k = {2,3,4,5,6}
m = {4,5,6,7,8,10,11}
k.update(m)
print(k)
# Out:
# {2, 3, 4, 5, 6, 7, 8, 10, 11}

# %%
g = {"a":1, "b":2, "c":3}
v = {"d":4}
g.update(v)
print(g)
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %%
for x,y in g:
    print(x,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-bab1a4fdbe33> in <module>
# ----> 1 for x,y in g:
#       2     print(x,y)
#
# ValueError: not enough values to unpack (expected 2, got 1)
